# %% [markdown]
# <a href="https://www.kaggle.com/code/gpreda/telescoping-fraction?scriptVersionId=297853147" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import kaggle_benchmarks as kbench
import math

@kbench.task(name="calculate_telescoping_series")
def calculate_telescoping_series(llm):
    """
    Asks the LLM to calculate the sum of the series 1/(n*(n+1)) from n=1 to 99.
    This is a classic telescoping series that sums to 1 - 1/100.
    """
    prompt = "Calculate the value of the following sum: 1/(1*2) + 1/(2*3) + 1/(3*4) + ... + 1/(99*100). Respond with only the final numerical result."

    response = llm.prompt(prompt)

    if response is None:
        kbench.assertions.assert_fail("Model did not return a parsable value.")
        return

    kbench.assertions.assert_contains_regex(
        r"0.99",
        response,
        expectation="The model should correctly output that the result is 0.99."
    )

calculate_telescoping_series.run(kbench.llm)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='2d8a4697-9a56-4a7a-9854-fa6e25cb2743'>
#   <div id="b30a355c-7294-45ed-b5d0-8bc360a88774" data-root-id="2d8a4697-9a56-4a7a-9854-fa6e25cb2743" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...
