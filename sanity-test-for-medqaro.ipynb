# %% [markdown]
# <a href="https://www.kaggle.com/code/gpreda/sanity-test-for-medqaro?scriptVersionId=298675565" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Introduction
#
# Quick test for the dataset.
#
# We will use this dataset to create a Kaggle Benchmark.
# See here for more details: [MedQARo - Benchmark for Medical Q and A in Romanian](https://www.kaggle.com/benchmarks/gpreda/medqaro-benchmark-for-medical-q-and-a-in-romanian).
#
# The MedQARo: A Large-Scale Benchmark for Medical Question Answering in Romanian (on Kaggle: https://www.kaggle.com/datasets/gpreda/medqaro-benchmark-for-medical-q-and-a-in-romanian) dataset is used to create the tests in the tasks.
#
# In this Notebook we quikly glimpse the dataset.

# %%
import numpy as np
import pandas as pd
import json
import tiktoken



pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/medqaro-benchmark-for-medical-q-and-a-in-romanian/romedqa_val_dataset.csv
# /kaggle/input/medqaro-benchmark-for-medical-q-and-a-in-romanian/romedqa_test_dataset.csv
# /kaggle/input/medqaro-benchmark-for-medical-q-and-a-in-romanian/romedqa_train_dataset.csv
# /kaggle/input/medqaro-benchmark-for-medical-q-and-a-in-romanian/cross_center_cross_diagnosis.csv

# %% [markdown]
# We will use the validation set.

# %%
val_df = pd.read_csv("/kaggle/input/medqaro-benchmark-for-medical-q-and-a-in-romanian/romedqa_val_dataset.csv")

# %% [markdown]
# # Glimpse the data

# %%
val_df.shape
# Out:
# (15328, 4)

# %%
val_df.head(2)
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0  Neoplasm mamar drept neglijat diagnostic si terapeutic - std. IV (cT3cN2M1oss), biopsiat (HP: k ductal invaziv cu arii restranse de carcinom lobular invaziv, IHC: ER+ 90-95%, PR+ 10-15%, CerbB2++, Ki67+ 3-5%, CISH-), HT (Anastrozol 11.2015 - 06.2016), progresie biochimica, HT  (Exemestan), RT-M1oss (T5-L1 / cervicotoracal 30 Gy), progresie biochimica + PD M1oss, MCT (11 x Docetaxel) - toxicitate neurologica inacceptatbila, HT (Tamoxifen (09.2018 - 03.2019), progresie biochimica + PD M1hep, MCT (6 x Caelyx), PD M1hep,  MCT (14 x Capecitabina) si tratament cu bifosfonati (acid zoledronic din 11.2015), PD (M1HEP), M1 cerebel -Gamma knife, MCT (Vinorelbine Z1-Z8) - 3 serii, progresie biochimica, MCT (Gemcitabina Z1,Z8,Z15) -5 serii, PD (M1HEP),  PD (M1BRA ) - RT whole brain, MCT (6 x Docetaxel), PD M1hep, HT (Fulvestrant + inhib. CDK4/6 (Palbociclib; 11.2021-02.2022), PD M1 hep, in curs de Letrozol (din 03.2022)     Infectie SARS CoV2 02.2022 Neutropenie grad III Z15 ciclul I Palbociclib.Neutropenie grad III dupa ciclul 3 de Docetaxel  Fractura bazin (os pubian stang).PNPS gr II - PERSISTENTA Antecedente de neutropenie gr II dupa al 4-lea ciclu Caelyx. Antecedente de celulita membru superior drept Osteopenie L1-L4 si femur stang. Spondiloza toraco-lombara Stenoza moderata canal rahidian T10-T11. Stenoza intracanalara sacrata si intraforaminala stanga S1-S2 si S2-S3 Multiple protruzii discale lombare.Litiaza biliara   07.2012 - Mamografie san dr (Dr. Ilie Angela, REGINA MARIA): retractie mamelonara dreapta de circa 6 luni; ingrosare tegumentara periareolara, cu minima distorsiune vizibila la nivelul canalului central; doua focare de microcalcificari cu caractere mamografice mai probabil benigne, putin numeroase, vizibile la nivelul canalului central; opacitate infracentimetrica cu contur net si diametrul maxim de 5 mm, vizibila pe incidenta CC a sanului, la 3,5 cm de mamelon (posibil lipom). Concluzii: ingrosare tegumentara periareolara, cu minima distorsiune vizibila la nivelul canalului central; focare de microcalcificari cu caractere mamografice mai probabil benigne. 11.2012 - Eco san dr (Dr Ilie Angela, REGINA MARIA): Retractie mamelonara. San drept: fara formatiuni chistice sau solide decelabile ecografic; in cadranele externe, predominant CSE, multiple formatiuni hiperecogene, bine delimitate, cu dimensiuni cuprinse intre 1/2 mm si 11/5 mm - lipoame; paraareolar, ora 8, se mentin microcalcificarile de la examinarea anterioara; CII, paraareolar, distorsiune arhitecturala cu macrocalcificari incluse - leziune incerta; adenopatie axilara cu caracter inflamator. BIRADS 4. Concluzie: leziune incerta. 04.2013 - Eco san bilaterala (Dr.  Ilie Angela, REGINA MARIA): Retractie mamelonara dreapta. San drept: multiple formatiuni hiperecogene cu dimensiuni cuprinse intre 3/5 mm si 12/7 mm, distribuite in intreg sanul predominant in cadranele externe - lipoame; paraareolar, ora 7-8, cateva microcalcificari incluse (stationar fata de examinarea din 09.07.2012) intr-o distorsiune arhitecturala - leziune incerta; adenopatie axilara dreapta de 14/9 mm cu caracter inflamator. San stang: fara formatiuni chistice sau solide decelabile ecografic. BIRADS 4. Concluzie: leziune incerta san drept. 08.2014 - Rx bazin si coloana lombara (Dr Sorin Constantinescu - Fundatia "Dr Victor Babes"): Osteofite la nivelul versantilor articulari sacroiliaci in portiunea inferioara; tendinta la hiperlordoza coloanei lombare; pensarea spatiului vertebral L5-S1; osteofite anterioare la nivelul platourilor vertebrale superioare etajate L1-L4; modificari osteocondensante la nivelul platourilor vertebrale superioare L2-L4, in portiunile anterioare. 09.2014 - Analize (Dr Szabo Cristian - Fundatia "Dr Victor Babes"): Fibrinogen: 483 mg/dl; CRP: 1.67 mg/dl; electroforeza proteinelor serice: fara modificari; TSH in limite normale; Ac antinucleari, Ac anti-CCP, factor reumatoid: in limite normale. 07.2015 - IRM coloana lombara (Dr Sandu Aurelia - SCU "Bagdazar Arseni"): I ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
#
#                                                                                       Intrebare  \
# 0  Care este tipul chimioterapiei aplicate acestui pacient: adjuvant, neoadjuvant sau paliativ?
# 1                                          Unde s-au răspândit metastazele la această pacientă?
#
#   Raspuns
# 0     3.0
# 1       0

# %% [markdown]
# # Statistics

# %% [markdown]
# ## Length of texts
#
# Let's check the length of texts in this dataset.

# %%
val_df.columns
# Out:
# Index(['Unnamed: 0', 'Epicriza', 'Intrebare', 'Raspuns'], dtype='object')

# %%
for col in ['Epicriza', 'Intrebare', 'Raspuns']:
    val_df[f"text_length_{col}"] = val_df[col].str.len()

# %% [markdown]
# ## Number of words
#
# And let's check the number of words.

# %%
for col in ['Epicriza', 'Intrebare', 'Raspuns']:
    val_df[f"word_count_{col}"] = val_df[col].str.split().str.len()

# %% [markdown]
# ## Number of tokens
#
# And then let's check the number of tokens.

# %%
encoding = tiktoken.get_encoding("cl100k_base")

for col in ['Epicriza', 'Intrebare', 'Raspuns']:
    val_df[f"token_count_{col}"] = val_df[col].apply(lambda x: len(encoding.encode(str(x))))

# %% [markdown]
# Now, let's calculate few stats.

# %%
val_df.columns
# Out:
# Index(['Unnamed: 0', 'Epicriza', 'Intrebare', 'Raspuns',
#        'text_length_Epicriza', 'text_length_Intrebare', 'text_length_Raspuns',
#        'word_count_Epicriza', 'word_count_Intrebare', 'word_count_Raspuns',
#        'token_count_Epicriza', 'token_count_Intrebare', 'token_count_Raspuns'],
#       dtype='object')

# %%
sel_columns = ['text_length_Epicriza', 'text_length_Intrebare', 'text_length_Raspuns',
       'word_count_Epicriza', 'word_count_Intrebare', 'word_count_Raspuns',
       'token_count_Epicriza', 'token_count_Intrebare', 'token_count_Raspuns']

# %%
val_df[sel_columns].head()
# Out:
#    text_length_Epicriza  text_length_Intrebare  text_length_Raspuns  \
# 0                 53890                     92                    3
# 1                 10341                     52                    1
# 2                 15163                     63                   10
# 3                 20842                     43                    2
# 4                 14674                     66                    5
#
#    word_count_Epicriza  word_count_Intrebare  word_count_Raspuns  \
# 0                 7554                    11                   1
# 1                 1314                     7                   1
# 2                 2201                     8                   3
# 3                 2957                     6                   1
# 4                 2208                     9                   1
#
#    token_count_Epicriza  token_count_Intrebare  token_count_Raspuns
# 0                 19337                     29                    3
# 1                  3779                     20                    1
# 2                  5668                     16                    4
# 3                  7585                     14                    1
# 4                  5562                     20                    3

# %%
stats = []
for col in sel_columns:
    stats.append((col, val_df[col].describe().to_json()))

# %% [markdown]
# Let's put now the data in a pandas DataFrame.

# %%
rows = []
for name, stats_json in stats:
    stats_dict = json.loads(stats_json)
    stats_dict["metric"] = name
    rows.append(stats_dict)

stats_df = pd.DataFrame(rows)

stats_df = stats_df.set_index("metric")

# %% [markdown]
# It is much easier to see the results if be transpose this DataFrame.

# %%
stats_df.T
# Out:
# metric  text_length_Epicriza  text_length_Intrebare  text_length_Raspuns  \
# count           15328.000000           15328.000000         15328.000000
# mean            21356.462813              63.716336             9.211639
# std             12363.612738              17.157955            42.068812
# min              2425.000000              18.000000             1.000000
# 25%             11479.000000              52.000000             2.000000
# 50%             19766.000000              64.000000             3.000000
# 75%             27947.000000              75.000000             7.000000
# max             66139.000000             129.000000           969.000000
#
# metric  word_count_Epicriza  word_count_Intrebare  word_count_Raspuns  \
# count          15328.000000          15328.000000        15328.000000
# mean            2916.088727              9.104123            1.945720
# std             1681.750890              2.550358            6.255238
# min              332.000000              2.000000            1.000000
# 25%             1623.000000              7.000000            1.000000
# 50%             2676.000000              9.000000            1.000000
# 75%             3735.000000             11.000000            1.000000
# max             9483.000000             18.000000          150.000000
#
# metric  token_count_Epicriza  token_count_Intrebare  token_count_Raspuns
# count           15328.000000           15328.000000         15328.000000
# mean             7671.055324              19.777401             4.438283
# std              4431.369959               5.507188            18.102659
# min               855.000000               6.000000             1.000000
# 25%              4210.000000              16.000000             1.000000
# 50%              7066.000000              20.000000             2.000000
# 75%              9796.000000              23.000000             3.000000
# max             27848.000000              37.000000           408.000000

# %% [markdown]
# That's all for now.
#
# Check the Benchmark results here: [MedQARo: Benchmark for Medical Q&A in Romanian](https://www.kaggle.com/benchmarks/gpreda/medqaro-benchmark-for-medical-q-and-a-in-romanian)
